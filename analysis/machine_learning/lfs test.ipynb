# %%
import pandas as pd

# %%
x = pd.read_csv(r'https://github.com/chrisstrods/aflengine/raw/master/bench/matches.csv')

# %%
x.head()
# Out:
#   round            venue        date  day  time    crowd      hteam hteam_q1  \
# 0     1   Moorabbin Oval  1-Apr-1972  Sat  2:10  21373.0   St Kilda   2.1.13
# 1     1     Princes Park  1-Apr-1972  Sat  2:10  33601.0    Carlton   2.4.16
# 2     1  Glenferrie Oval  1-Apr-1972  Sat  2:10  21513.0   Hawthorn   4.3.27
# 3     1     Western Oval  1-Apr-1978  Sat  2:10  20420.0  Footscray   2.4.16
# 4     1     Princes Park  1-Apr-1978  Sat  2:10  11986.0   Hawthorn   3.6.24
#
#   hteam_q2  hteam_q3  ... hteam_et ateam_et season       matchid homeodds  \
# 0  11.6.72  13.10.88  ...      NaN      NaN   1972  197201NORSTK      NaN
# 1   5.9.39   7.11.53  ...      NaN      NaN   1972  197201CARFIT      NaN
# 2   9.4.58  10.10.70  ...      NaN      NaN   1972  197201HAWMEL      NaN
# 3   9.7.61  10.11.71  ...      NaN      NaN   1978  197801FOTNOR      NaN
# 4  7.11.53  14.11.95  ...      NaN      NaN   1978  197801HAWMEL      NaN
#
#   homeline awayodds awayline hscore  ascore
# ...
