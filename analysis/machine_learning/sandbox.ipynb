# %%
import pandas as pd
match_path = '/Users/t_raver9/Desktop/projects/aflengine/analysis/machine_learning/src/player_data/data/matches_with_player_agg.csv'
players_path = '/Users/t_raver9/Desktop/projects/aflengine/analysis/machine_learning/src/player_data/data/players_with_player_stat_totals.csv'
matches = pd.read_csv(match_path)
players = pd.read_csv(players_path)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Applications/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,27,34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Using data for predictions

# %% [markdown]
# Step 1: Need a function to retrieve the player data for each team. This will require manual entry of players, for now. If the player has never played before, we'll add the mean values for the categories in which they aren't found.

# %%
pd.set_option('max_columns',500)
players.tail()
# Out:
#         Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 627690      627690        627690          627690            627690
# 627691      627691        627691          627691            627691
# 627692      627692        627692          627692            627692
# 627693      627693        627693          627693            627693
# 627694      627694        627694          627694            627694
#
#         Unnamed: 0.1.1.1.1  Unnamed: 0.1.1.1.1.1  Unnamed: 0.1.1.1.1.1.1  \
# 627690              627690                627690                  627690
# 627691              627691                627691                  627691
# 627692              627692                627692                  627692
# 627693              627693                627693                  627693
# 627694              627694                627694                  627694
#
#         Unnamed: 0.1.1.1.1.1.1.1  AFLfantasy  Supercoach  behinds  bounces  \
# 627690                    563034        27.0        47.0      0.0      0.0
# 627691                    563424        61.0        50.0      1.0      0.0
# 627692                    563787        31.0        28.0      1.0      1.0
# 627693                    564269        61.0        58.0      1.0      0.0
# 627694                    564478        12.0         6.0      0.0      0.0
#
#         brownlow  clangers  clearances  contested_marks  contested_poss  \
# 627690       0.0       0.0         0.0              0.0             4.0
# 627691       0.0       5.0         1.0              0.0             6.0
# 627692       0.0       1.0         0.0              1.0             4.0
# 627693       0.0       3.0         0.0              2.0             9.0
# 627694       0.0       1.0         0.0              0.0             2.0
#
#         disposals first_name  frees_against  frees_for                fullkey  \
# 627690        8.0  Zephaniah            0.0        0.0  201219FOTNORzskinner2
# 627691       12.0  Zephaniah            1.0        3.0  201220FOTRCHzskinner7
# 627692        8.0  Zephaniah            0.0        1.0  201221FOTSYDzskinner3
# 627693       17.0  Zephaniah            0.0        0.0  201222FOTGEEzskinner8
# 627694        2.0  Zephaniah            0.0        0.0  201223BRSFOTzskinner1
#
#                  fullname  goal_assists  goals  handballs  hitouts homeAway  \
# 627690  Zephaniah Skinner           2.0    0.0        6.0      1.0     Home
# 627691  Zephaniah Skinner           0.0    2.0        5.0      4.0     Away
# 627692  Zephaniah Skinner           0.0    0.0        5.0      1.0     Home
# 627693  Zephaniah Skinner           1.0    1.0        9.0      0.0     Away
# 627694  Zephaniah Skinner           0.0    0.0        1.0      0.0     Away
#
#         inside50  kicks last_name  marks  marks_in_50       matchid  \
# 627690       1.0    2.0   Skinner    0.0          0.0  201219FOTNOR
# 627691       1.0    7.0   Skinner    3.0          2.0  201220FOTRCH
# 627692       0.0    3.0   Skinner    3.0          1.0  201221FOTSYD
# 627693       2.0    8.0   Skinner    4.0          1.0  201222FOTGEE
# 627694       1.0    1.0   Skinner    1.0          0.0  201223BRSFOT
#
#           namekey  number  one_percenters           playerid  rebound50  \
# 627690  zskinner2    26.0             2.0  Zephaniah_Skinner        0.0
# 627691  zskinner7    26.0             0.0  Zephaniah_Skinner        0.0
# 627692  zskinner3    26.0             1.0  Zephaniah_Skinner        0.0
# 627693  zskinner8    26.0             1.0  Zephaniah_Skinner        0.0
# 627694  zskinner1     0.0             1.0  Zephaniah_Skinner        0.0
#
#         tackles       team   tog  uncontested_poss  centre_clearances  \
# 627690      2.0  Footscray  73.0               4.0                0.0
# 627691      1.0  Footscray  75.0               6.0                0.0
# 627692      0.0  Footscray  74.0               4.0                0.0
# 627693      0.0  Footscray  73.0               8.0                0.0
# 627694      1.0  Footscray  28.0               1.0                0.0
#
#         disposal_efficiency  effective_disposals  intercepts  metres_gained  \
# 627690                 87.5                  7.0         0.0            0.0
# 627691                 41.7                  5.0         0.0            0.0
# 627692                 62.5                  5.0         0.0            0.0
# 627693                 52.9                  9.0         0.0            0.0
# 627694                  0.0                  0.0         0.0            0.0
#
#         stoppage_clearances  score_involvements  tackles_in_50  turnovers  \
# 627690                  0.0                 0.0            0.0        0.0
# 627691                  0.0                 0.0            0.0        0.0
# 627692                  0.0                 0.0            0.0        0.0
# 627693                  0.0                 0.0            0.0        0.0
# 627694                  0.0                 0.0            0.0        0.0
#
#         season round  round_num  season_AFLfantasy  career_AFLfantasy  \
# 627690    2012    19         19          24.666667          22.000000
# 627691    2012    20         20          33.750000          29.800000
# 627692    2012    21         21          33.200000          30.000000
# 627693    2012    22         22          37.833333          34.428571
# 627694    2012    23         23          34.142857          31.625000
#
#         season_Supercoach  career_Supercoach  season_behinds  career_behinds  \
# 627690          30.666667          24.000000        0.333333        0.500000
# 627691          35.500000          29.200000        0.500000        0.600000
# 627692          34.000000          29.000000        0.600000        0.666667
# 627693          38.000000          33.142857        0.666667        0.714286
# 627694          33.428571          29.750000        0.571429        0.625000
#
#         season_bounces  career_bounces  season_brownlow  career_brownlow  \
# 627690        0.000000        0.250000              0.0              0.0
# 627691        0.000000        0.200000              0.0              0.0
# 627692        0.200000        0.333333              0.0              0.0
# 627693        0.166667        0.285714              0.0              0.0
# 627694        0.142857        0.250000              0.0              0.0
#
#         season_clangers  career_clangers  season_clearances  \
# 627690         0.666667         0.750000           0.000000
# 627691         1.750000         1.600000           0.250000
# 627692         1.600000         1.500000           0.200000
# 627693         1.833333         1.714286           0.166667
# 627694         1.714286         1.625000           0.142857
#
#         career_clearances  season_contested_marks  career_contested_marks  \
# 627690           0.000000                0.000000                0.000000
# 627691           0.200000                0.000000                0.000000
# 627692           0.166667                0.200000                0.166667
# 627693           0.142857                0.500000                0.428571
# 627694           0.125000                0.428571                0.375000
#
#         season_contested_poss  career_contested_poss  season_disposals  \
# 627690               2.666667               2.000000          5.333333
# 627691               3.500000               2.800000          7.000000
# 627692               3.600000               3.000000          7.200000
# 627693               4.500000               3.857143          8.833333
# 627694               4.142857               3.625000          7.857143
#
#         career_disposals  season_frees_against  career_frees_against  \
# 627690          4.500000              0.000000              0.250000
# 627691          6.000000              0.250000              0.400000
# 627692          6.333333              0.200000              0.333333
# 627693          7.857143              0.166667              0.285714
# 627694          7.125000              0.142857              0.250000
#
#         season_frees_for  career_frees_for  season_goal_assists  \
# 627690          0.333333          0.250000             1.000000
# 627691          1.000000          0.800000             0.750000
# 627692          1.000000          0.833333             0.600000
# 627693          0.833333          0.714286             0.666667
# 627694          0.714286          0.625000             0.571429
#
#         career_goal_assists  season_goals  career_goals  season_handballs  \
# 627690             0.750000      0.666667      0.500000          3.000000
# 627691             0.600000      1.000000      0.800000          3.500000
# 627692             0.500000      0.800000      0.666667          3.800000
# 627693             0.571429      0.833333      0.714286          4.666667
# 627694             0.500000      0.714286      0.625000          4.142857
#
#         career_handballs  season_hitouts  career_hitouts  season_inside50  \
# 627690          2.250000        0.333333        0.250000              1.0
# 627691          2.800000        1.250000        1.000000              1.0
# 627692          3.166667        1.200000        1.000000              0.8
# 627693          4.000000        1.000000        0.857143              1.0
# 627694          3.625000        0.857143        0.750000              1.0
#
#         career_inside50  season_kicks  career_kicks  season_marks  \
# 627690         1.000000      2.333333      2.250000      0.000000
# 627691         1.000000      3.500000      3.200000      0.750000
# 627692         0.833333      3.400000      3.166667      1.200000
# 627693         1.000000      4.166667      3.857143      1.666667
# 627694         1.000000      3.714286      3.500000      1.571429
#
#         career_marks  season_marks_in_50  career_marks_in_50  \
# 627690      0.500000            0.000000            0.250000
# 627691      1.000000            0.500000            0.600000
# 627692      1.333333            0.600000            0.666667
# 627693      1.714286            0.666667            0.714286
# 627694      1.625000            0.571429            0.625000
#
#         season_one_percenters  career_one_percenters  season_rebound50  \
# 627690               1.000000               0.750000               0.0
# 627691               0.750000               0.600000               0.0
# 627692               0.800000               0.666667               0.0
# 627693               0.833333               0.714286               0.0
# 627694               0.857143               0.750000               0.0
#
#         career_rebound50  season_tackles  career_tackles  season_tog  \
# 627690               0.0        1.666667        1.500000   43.000000
# 627691               0.0        1.500000        1.400000   51.000000
# 627692               0.0        1.200000        1.166667   55.600000
# 627693               0.0        1.000000        1.000000   58.500000
# 627694               0.0        1.000000        1.000000   54.142857
#
#         career_tog  season_uncontested_poss  career_uncontested_poss  \
# 627690   39.750000                 2.666667                 2.500000
# 627691   46.800000                 3.500000                 3.200000
# 627692   51.333333                 3.600000                 3.333333
# 627693   54.428571                 4.333333                 4.000000
# 627694   51.125000                 3.857143                 3.625000
#
#         season_centre_clearances  career_centre_clearances  \
# 627690                       0.0                       0.0
# 627691                       0.0                       0.0
# 627692                       0.0                       0.0
# 627693                       0.0                       0.0
# 627694                       0.0                       0.0
#
#         season_disposal_efficiency  career_disposal_efficiency  \
# 627690                   64.733333                   48.550000
# 627691                   58.975000                   47.180000
# 627692                   59.680000                   49.733333
# 627693                   58.550000                   50.185714
# 627694                   50.185714                   43.912500
#
#         season_effective_disposals  career_effective_disposals  \
# 627690                    3.666667                    2.750000
# 627691                    4.000000                    3.200000
# 627692                    4.200000                    3.500000
# 627693                    5.000000                    4.285714
# 627694                    4.285714                    3.750000
#
#         season_intercepts  career_intercepts  season_metres_gained  \
# 627690                0.0                0.0                   0.0
# 627691                0.0                0.0                   0.0
# 627692                0.0                0.0                   0.0
# 627693                0.0                0.0                   0.0
# 627694                0.0                0.0                   0.0
#
#         career_metres_gained  season_stoppage_clearances  \
# 627690                   0.0                         0.0
# 627691                   0.0                         0.0
# 627692                   0.0                         0.0
# 627693                   0.0                         0.0
# 627694                   0.0                         0.0
#
#         career_stoppage_clearances  season_score_involvements  \
# 627690                         0.0                        0.0
# 627691                         0.0                        0.0
# 627692                         0.0                        0.0
# 627693                         0.0                        0.0
# 627694                         0.0                        0.0
#
#         career_score_involvements  season_tackles_in_50  career_tackles_in_50  \
# 627690                        0.0                   0.0                   0.0
# 627691                        0.0                   0.0                   0.0
# 627692                        0.0                   0.0                   0.0
# 627693                        0.0                   0.0                   0.0
# 627694                        0.0                   0.0                   0.0
#
#         season_turnovers  career_turnovers  career_games_played  \
# 627690               0.0               0.0                    4
# 627691               0.0               0.0                    5
# 627692               0.0               0.0                    6
# 627693               0.0               0.0                    7
# 627694               0.0               0.0                    8
#
#         season_games_played  next_matchid
# 627690                    3  201220FOTRCH
# 627691                    4  201221FOTSYD
# 627692                    5  201222FOTGEE
# 627693                    6  201223BRSFOT
# 627694                    7           NaN

# %% [markdown]
# As an example, try to find Melbourne's team for round 1.

# %%
melb_list = ['Neville_Jetta','Jake_Lever','Steven_May']

# %%
last_games = pd.DataFrame(columns = players.columns)
for player in melb_list:
    last_game_row = players[(players['playerid']==player) & (players['next_matchid'].isna())]
    last_games = last_games.append(last_game_row)

# %%
last_games
# Out:
#        Unnamed: 0 Unnamed: 0.1 Unnamed: 0.1.1 Unnamed: 0.1.1.1  \
# 455512     455512       455512         455512           455512
# 296916     296916       296916         296916           296916
# 573056     573056       573056         573056           573056
#
#        Unnamed: 0.1.1.1.1 Unnamed: 0.1.1.1.1.1 Unnamed: 0.1.1.1.1.1.1  \
# 455512             455512               455512                 455512
# 296916             296916               296916                 296916
# 573056             573056               573056                 573056
#
#        Unnamed: 0.1.1.1.1.1.1.1  AFLfantasy  Supercoach  behinds  bounces  \
# 455512                   625694        47.0        48.0      0.0      0.0
# 296916                   627258        51.0        60.0      0.0      0.0
# 573056                   626300        56.0        88.0      0.0      0.0
#
#         brownlow  clangers  clearances  contested_marks  contested_poss  \
# 455512       0.0       0.0         0.0              1.0             5.0
# 296916       0.0       4.0         0.0              1.0             5.0
# 573056       0.0       1.0         1.0              1.0             4.0
#
#         disposals first_name  frees_against  frees_for              fullkey  \
# 455512        9.0    Neville            0.0        1.0  201919MELSTKnjetta3
# 296916       14.0       Jake            0.0        0.0  201923MELNORjlever8
# 573056       14.0     Steven            0.0        1.0   201921COLMELsmay12
#
#              fullname  goal_assists  goals  handballs  hitouts homeAway  \
# 455512  Neville Jetta           0.0    0.0        6.0      0.0     Away
# 296916     Jake Lever           0.0    0.0        6.0      0.0     Away
# 573056     Steven May           0.0    0.0        2.0      0.0     Home
#
#         inside50  kicks last_name  marks  marks_in_50       matchid  namekey  \
# 455512       1.0    3.0     Jetta    3.0          0.0  201919MELSTK  njetta3
# 296916       0.0    8.0     Lever    5.0          0.0  201923MELNOR  jlever8
# 573056       0.0   12.0       May    5.0          0.0  201921COLMEL   smay12
#
#         number  one_percenters       playerid  rebound50  tackles       team  \
# 455512    39.0             3.0  Neville_Jetta        2.0      4.0  Melbourne
# 296916     8.0             4.0     Jake_Lever        4.0      0.0  Melbourne
# 573056     1.0             8.0     Steven_May        4.0      0.0  Melbourne
#
#          tog  uncontested_poss  centre_clearances  disposal_efficiency  \
# 455512  81.0               3.0                0.0                 77.8
# 296916  93.0              11.0                0.0                 64.3
# 573056  73.0               7.0                0.0                 85.7
#
#         effective_disposals  intercepts  metres_gained  stoppage_clearances  \
# 455512                  7.0         6.0          144.0                  0.0
# 296916                  9.0         8.0          169.0                  0.0
# 573056                 12.0         3.0          176.0                  1.0
#
#         score_involvements  tackles_in_50  turnovers season round round_num  \
# 455512                 0.0            0.0        1.0   2019    19        19
# 296916                 1.0            0.0        4.0   2019    23        23
# 573056                 2.0            0.0        1.0   2019    21        21
#
#         season_AFLfantasy  career_AFLfantasy  season_Supercoach  \
# 455512          42.428571          49.615385          49.857143
# 296916          59.875000          60.800000          70.750000
# 573056          57.750000          60.945736          70.750000
#
#         career_Supercoach  season_behinds  career_behinds  season_bounces  \
# 455512          54.720280            0.00        0.118881        0.142857
# 296916          71.546667            0.00        0.053333        0.250000
# 573056          74.085271            0.25        0.155039        0.125000
#
#         career_bounces  season_brownlow  career_brownlow  season_clangers  \
# 455512        0.132867              0.0         0.000000         2.714286
# 296916        0.200000              0.0         0.013333         2.625000
# 573056        0.379845              0.0         0.093023         2.875000
#
#         career_clangers  season_clearances  career_clearances  \
# 455512         1.482517              0.000           0.538462
# 296916         2.320000              0.125           0.080000
# 573056         2.573643              0.250           0.255814
#
#         season_contested_marks  career_contested_marks  season_contested_poss  \
# 455512                0.428571                0.286713               5.428571
# 296916                1.000000                0.866667               5.875000
# 573056                0.500000                0.806202               4.000000
#
#         career_contested_poss  season_disposals  career_disposals  \
# 455512               4.986014         10.714286         12.979021
# 296916               5.680000         14.625000         15.173333
# 573056               4.899225         15.125000         14.612403
#
#         season_frees_against  career_frees_against  season_frees_for  \
# 455512              1.857143              0.699301          1.428571
# 296916              0.500000              0.866667          0.375000
# 573056              1.125000              0.914729          0.625000
#
#         career_frees_for  season_goal_assists  career_goal_assists  \
# 455512          1.090909             0.142857             0.279720
# 296916          0.933333             0.125000             0.093333
# 573056          0.860465             0.000000             0.124031
#
#         season_goals  career_goals  season_handballs  career_handballs  \
# 455512         0.000      0.167832          5.142857          6.482517
# 296916         0.000      0.040000          5.000000          5.106667
# 573056         0.125      0.170543          2.125000          4.240310
#
#         season_hitouts  career_hitouts  season_inside50  career_inside50  \
# 455512           0.000        0.000000         1.285714         1.062937
# 296916           0.000        0.026667         1.000000         1.333333
# 573056           0.125        0.124031         0.875000         1.077519
#
#         season_kicks  career_kicks  season_marks  career_marks  \
# 455512      5.571429      6.496503      2.714286      3.300699
# 296916      9.625000     10.066667      6.875000      5.573333
# 573056     13.000000     10.372093      3.875000      5.170543
#
#         season_marks_in_50  career_marks_in_50  season_one_percenters  \
# 455512               0.000            0.216783               3.714286
# 296916               0.000            0.053333               6.875000
# 573056               0.125            0.124031               7.625000
#
#         career_one_percenters  season_rebound50  career_rebound50  \
# 455512               2.727273          2.142857          1.419580
# 296916               5.533333          3.750000          3.240000
# 573056               7.333333          5.000000          3.775194
#
#         season_tackles  career_tackles  season_tog  career_tog  \
# 455512        2.857143        3.181818   78.714286   81.181818
# 296916        0.375000        1.253333   88.875000   86.080000
# 573056        1.125000        1.604651   83.875000   90.581395
#
#         season_uncontested_poss  career_uncontested_poss  \
# 455512                 5.142857                 7.958042
# 296916                 8.750000                 9.546667
# 573056                 7.875000                 8.434109
#
#         season_centre_clearances  career_centre_clearances  \
# 455512                       0.0                  0.013986
# 296916                       0.0                  0.013333
# 573056                       0.0                  0.007752
#
#         season_disposal_efficiency  career_disposal_efficiency  \
# 455512                   81.742857                   71.701399
# 296916                   72.100000                   76.790667
# 573056                   72.687500                   75.417054
#
#         season_effective_disposals  career_effective_disposals  \
# 455512                    8.857143                    9.398601
# 296916                   10.625000                   11.746667
# 573056                   11.250000                   11.162791
#
#         season_intercepts  career_intercepts  season_metres_gained  \
# 455512           5.428571           3.335664            108.142857
# 296916           7.875000           7.813333            236.500000
# 573056           5.000000           3.937984            307.250000
#
#         career_metres_gained  season_stoppage_clearances  \
# 455512             87.531469                       0.000
# 296916            252.280000                       0.125
# 573056            176.627907                       0.250
#
#         career_stoppage_clearances  season_score_involvements  \
# 455512                    0.181818                      2.000
# 296916                    0.066667                      1.625
# 573056                    0.147287                      1.875
#
#         career_score_involvements  season_tackles_in_50  career_tackles_in_50  \
# 455512                   1.545455                   0.0              0.027972
# 296916                   2.640000                   0.0              0.000000
# 573056                   1.480620                   0.0              0.015504
#
#         season_turnovers  career_turnovers career_games_played  \
# 455512          2.142857          0.930070                 143
# 296916          4.125000          2.973333                  75
# 573056          3.375000          2.217054                 129
#
#        season_games_played next_matchid
# 455512                   7          NaN
# 296916                   8          NaN
# 573056                   8          NaN

# %% [markdown]
# Work with a copy

# %%
from copy import deepcopy
df = deepcopy(last_games)

# %% [markdown]
# For each of these players, we need to take into account their performance in their previous game, i.e. we need to add this to their statistics for the upcoming game.

# %%
cols_to_update = [col for col in df.columns if (col[0:6] in ['career','season'])]
cols_to_update.remove('career_games_played')
cols_to_update.remove('season_games_played')
cols_to_update.remove('season')

# %%
def update_last_game(df):
    for idx,row in df.iterrows():
        df.at[idx,'career_games_played'] += 1
        df.at[idx,'season_games_played'] += 1
        
        for col in cols_to_update:
            single_game_col = col[7:] # This is the non-aggregate column, e.g. 'Supercoach' instead of 'career_Supercoach'
            if col[0:7] == 'career_':
                df.at[idx,col] = (df.at[idx,single_game_col] + (df.at[idx,col] * (df.at[idx,'career_games_played'] - 1))) / df.at[idx,'career_games_played']
            elif col[0:7] == 'season_':
                df.at[idx,col] = (df.at[idx,single_game_col] + (df.at[idx,col] * (df.at[idx,'season_games_played'] - 1))) / df.at[idx,'season_games_played']
            else:
                raise Exception('Column not found, check what columns you\'re passing')
                
    return df

# %%
updated = update_last_game(df)

# %%
updated
# Out:
#        Unnamed: 0 Unnamed: 0.1 Unnamed: 0.1.1 Unnamed: 0.1.1.1  \
# 455512     455512       455512         455512           455512
# 296916     296916       296916         296916           296916
# 573056     573056       573056         573056           573056
#
#        Unnamed: 0.1.1.1.1 Unnamed: 0.1.1.1.1.1 Unnamed: 0.1.1.1.1.1.1  \
# 455512             455512               455512                 455512
# 296916             296916               296916                 296916
# 573056             573056               573056                 573056
#
#        Unnamed: 0.1.1.1.1.1.1.1  AFLfantasy  Supercoach  behinds  bounces  \
# 455512                   625694        47.0        48.0      0.0      0.0
# 296916                   627258        51.0        60.0      0.0      0.0
# 573056                   626300        56.0        88.0      0.0      0.0
#
#         brownlow  clangers  clearances  contested_marks  contested_poss  \
# 455512       0.0       0.0         0.0              1.0             5.0
# 296916       0.0       4.0         0.0              1.0             5.0
# 573056       0.0       1.0         1.0              1.0             4.0
#
#         disposals first_name  frees_against  frees_for              fullkey  \
# 455512        9.0    Neville            0.0        1.0  201919MELSTKnjetta3
# 296916       14.0       Jake            0.0        0.0  201923MELNORjlever8
# 573056       14.0     Steven            0.0        1.0   201921COLMELsmay12
#
#              fullname  goal_assists  goals  handballs  hitouts homeAway  \
# 455512  Neville Jetta           0.0    0.0        6.0      0.0     Away
# 296916     Jake Lever           0.0    0.0        6.0      0.0     Away
# 573056     Steven May           0.0    0.0        2.0      0.0     Home
#
#         inside50  kicks last_name  marks  marks_in_50       matchid  namekey  \
# 455512       1.0    3.0     Jetta    3.0          0.0  201919MELSTK  njetta3
# 296916       0.0    8.0     Lever    5.0          0.0  201923MELNOR  jlever8
# 573056       0.0   12.0       May    5.0          0.0  201921COLMEL   smay12
#
#         number  one_percenters       playerid  rebound50  tackles       team  \
# 455512    39.0             3.0  Neville_Jetta        2.0      4.0  Melbourne
# 296916     8.0             4.0     Jake_Lever        4.0      0.0  Melbourne
# 573056     1.0             8.0     Steven_May        4.0      0.0  Melbourne
#
#          tog  uncontested_poss  centre_clearances  disposal_efficiency  \
# 455512  81.0               3.0                0.0                 77.8
# 296916  93.0              11.0                0.0                 64.3
# 573056  73.0               7.0                0.0                 85.7
#
#         effective_disposals  intercepts  metres_gained  stoppage_clearances  \
# 455512                  7.0         6.0          144.0                  0.0
# 296916                  9.0         8.0          169.0                  0.0
# 573056                 12.0         3.0          176.0                  1.0
#
#         score_involvements  tackles_in_50  turnovers season round round_num  \
# 455512                 0.0            0.0        1.0   2019    19        19
# 296916                 1.0            0.0        4.0   2019    23        23
# 573056                 2.0            0.0        1.0   2019    21        21
#
#         season_AFLfantasy  career_AFLfantasy  season_Supercoach  \
# 455512          43.000000          49.597222          49.625000
# 296916          58.888889          60.671053          69.555556
# 573056          57.555556          60.907692          72.666667
#
#         career_Supercoach  season_behinds  career_behinds  season_bounces  \
# 455512          54.673611        0.000000        0.118056        0.125000
# 296916          71.394737        0.000000        0.052632        0.222222
# 573056          74.192308        0.222222        0.153846        0.111111
#
#         career_bounces  season_brownlow  career_brownlow  season_clangers  \
# 455512        0.131944              0.0         0.000000         2.375000
# 296916        0.197368              0.0         0.013158         2.777778
# 573056        0.376923              0.0         0.092308         2.666667
#
#         career_clangers  season_clearances  career_clearances  \
# 455512         1.472222           0.000000           0.534722
# 296916         2.342105           0.111111           0.078947
# 573056         2.561538           0.333333           0.261538
#
#         season_contested_marks  career_contested_marks  season_contested_poss  \
# 455512                0.500000                0.291667               5.375000
# 296916                1.000000                0.868421               5.777778
# 573056                0.555556                0.807692               4.000000
#
#         career_contested_poss  season_disposals  career_disposals  \
# 455512               4.986111         10.500000         12.951389
# 296916               5.671053         14.555556         15.157895
# 573056               4.892308         15.000000         14.607692
#
#         season_frees_against  career_frees_against  season_frees_for  \
# 455512              1.625000              0.694444          1.375000
# 296916              0.444444              0.855263          0.333333
# 573056              1.000000              0.907692          0.666667
#
#         career_frees_for  season_goal_assists  career_goal_assists  \
# 455512          1.090278             0.125000             0.277778
# 296916          0.921053             0.111111             0.092105
# 573056          0.861538             0.000000             0.123077
#
#         season_goals  career_goals  season_handballs  career_handballs  \
# 455512      0.000000      0.166667          5.250000          6.479167
# 296916      0.000000      0.039474          5.111111          5.118421
# 573056      0.111111      0.169231          2.111111          4.223077
#
#         season_hitouts  career_hitouts  season_inside50  career_inside50  \
# 455512        0.000000        0.000000         1.250000         1.062500
# 296916        0.000000        0.026316         0.888889         1.315789
# 573056        0.111111        0.123077         0.777778         1.069231
#
#         season_kicks  career_kicks  season_marks  career_marks  \
# 455512      5.250000      6.472222      2.750000      3.298611
# 296916      9.444444     10.039474      6.666667      5.565789
# 573056     12.888889     10.384615      4.000000      5.169231
#
#         season_marks_in_50  career_marks_in_50  season_one_percenters  \
# 455512            0.000000            0.215278               3.625000
# 296916            0.000000            0.052632               6.555556
# 573056            0.111111            0.123077               7.666667
#
#         career_one_percenters  season_rebound50  career_rebound50  \
# 455512               2.729167          2.125000          1.423611
# 296916               5.513158          3.777778          3.250000
# 573056               7.338462          4.888889          3.776923
#
#         season_tackles  career_tackles  season_tog  career_tog  \
# 455512        3.000000        3.187500   79.000000   81.180556
# 296916        0.333333        1.236842   89.333333   86.171053
# 573056        1.000000        1.592308   82.666667   90.446154
#
#         season_uncontested_poss  career_uncontested_poss  \
# 455512                 4.875000                 7.923611
# 296916                 9.000000                 9.565789
# 573056                 7.777778                 8.423077
#
#         season_centre_clearances  career_centre_clearances  \
# 455512                       0.0                  0.013889
# 296916                       0.0                  0.013158
# 573056                       0.0                  0.007692
#
#         season_disposal_efficiency  career_disposal_efficiency  \
# 455512                   81.250000                   71.743750
# 296916                   71.233333                   76.626316
# 573056                   74.133333                   75.496154
#
#         season_effective_disposals  career_effective_disposals  \
# 455512                    8.625000                    9.381944
# 296916                   10.444444                   11.710526
# 573056                   11.333333                   11.169231
#
#         season_intercepts  career_intercepts  season_metres_gained  \
# 455512           5.500000           3.354167            112.625000
# 296916           7.888889           7.815789            229.000000
# 573056           4.777778           3.930769            292.666667
#
#         career_metres_gained  season_stoppage_clearances  \
# 455512             87.923611                    0.000000
# 296916            251.184211                    0.111111
# 573056            176.623077                    0.333333
#
#         career_stoppage_clearances  season_score_involvements  \
# 455512                    0.180556                   1.750000
# 296916                    0.065789                   1.555556
# 573056                    0.153846                   1.888889
#
#         career_score_involvements  season_tackles_in_50  career_tackles_in_50  \
# 455512                   1.534722                   0.0              0.027778
# 296916                   2.618421                   0.0              0.000000
# 573056                   1.484615                   0.0              0.015385
#
#         season_turnovers  career_turnovers career_games_played  \
# 455512          2.000000          0.930556                 144
# 296916          4.111111          2.986842                  76
# 573056          3.111111          2.207692                 130
#
#        season_games_played next_matchid
# 455512                   8          NaN
# 296916                   9          NaN
# 573056                   9          NaN

# %%
cols_to_update
# Out:
# ['season_AFLfantasy',
#  'career_AFLfantasy',
#  'season_Supercoach',
#  'career_Supercoach',
#  'season_behinds',
#  'career_behinds',
#  'season_bounces',
#  'career_bounces',
#  'season_brownlow',
#  'career_brownlow',
#  'season_clangers',
#  'career_clangers',
#  'season_clearances',
#  'career_clearances',
#  'season_contested_marks',
#  'career_contested_marks',
#  'season_contested_poss',
#  'career_contested_poss',
#  'season_disposals',
#  'career_disposals',
#  'season_frees_against',
#  'career_frees_against',
#  'season_frees_for',
#  'career_frees_for',
#  'season_goal_assists',
#  'career_goal_assists',
#  'season_goals',
#  'career_goals',
#  'season_handballs',
#  'career_handballs',
#  'season_hitouts',
#  'career_hitouts',
#  'season_inside50',
#  'career_inside50',
#  'season_kicks',
#  'career_kicks',
#  'season_marks',
#  'career_marks',
#  'season_marks_in_50',
#  'career_marks_in_50',
#  'season_one_percenters',
#  'career_one_percenters',
#  'season_rebound50',
#  'career_rebound50',
#  'season_tackles',
#  'career_tackles',
#  'season_tog',
#  'career_tog',
#  'season_uncontested_poss',
#  'career_uncontested_poss',
#  'season_centre_clearances',
#  'career_centre_clearances',
#  'season_disposal_efficiency',
#  'career_disposal_efficiency',
#  'season_effective_disposals',
#  'career_effective_disposals',
#  'season_intercepts',
#  'career_intercepts',
#  'season_metres_gained',
#  'career_metres_gained',
#  'season_stoppage_clearances',
#  'career_stoppage_clearances',
#  'season_score_involvements',
#  'career_score_involvements',
#  'season_tackles_in_50',
#  'career_tackles_in_50',
#  'season_turnovers',
#  'career_turnovers']
